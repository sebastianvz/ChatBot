# %%
import pandas as pd
import nltk 
import numpy as np
import re
from nltk.stem import wordnet # to perform lemmitization
from sklearn.feature_extraction.text import CountVectorizer # to perform bow
from sklearn.feature_extraction.text import TfidfVectorizer # to perform tfidf
from nltk import pos_tag # for parts of speech
from sklearn.metrics import pairwise_distances # to perfrom cosine similarity
from nltk import word_tokenize # to create tokens
from nltk.corpus import stopwords # for stop words

# %%
df=pd.read_excel('dialog_talk_agent.xlsx')
df.head(20)
# Out:
#                         Contexto                                          Respuesta
# 0                          Putty  Abrir Putty ve al link : https://github.com/k1...
# 1             Conectarse a cubiq  Abrir Putty ve al link : https://github.com/k1...
# 2                            VPN  Verificar VPN ve al link : https://github.com/...
# 3                       Licencia  Verificar Licencia ve al link : https://github...
# 4                   Ver Licencia  Verificar Licencia ve al link : https://github...
# 5             comprobar licencia  Verificar Licencia ve al link : https://github...
# 6              Verficar licencia  Verificar Licencia ve al link : https://github...
# 7              comprobar camara.  Camara conectada ve al link : https://github.c...
# 8               verificar camara  Camara conectada ve al link : https://github.c...
# 9                     ver camara  Camara conectada ve al link : https://github.c...
# 10              Camara conectada  Camara conectada ve al link : https://github.c...
# 11                   profundidad  Camara conectada ve al link : https://github.c...
# 12              verificar camara  Camara conectada ve al link : https://github.c...
# 13  comprobar camara profundidad  Camara conectada ve al link : https://github.c...
# 14            Camara profundidad  Camara conectada ve al link : https://github.c...
# 15      comprobar camara externa  Camara externa ve al link : https://github.com...
# 16      verificar camara externa  Camara externa ve al link : https://github.com...
# 17                Camara externa  Camara externa ve al link : https://github.com...
# 18                       Medidas  Las medidas de Cubiq ve al link: https://githu...
# 19             Medidas estan mal  Las medidas de Cubiq ve al link: https://githu...

# %%
df.shape
# Out:
# (1592, 2)

# %%
df.ffill(axis = 0,inplace=True) # fills the null value with the previous value.
df
# Out:
#                                Context                                  Text Response
# 0       Tell me about your personality    Just think of me as the ace up your sleeve.
# 1            I want to know you better  I can help you work smarter instead of harder
# 2                      Define yourself  I can help you work smarter instead of harder
# 3                    Describe yourself  I can help you work smarter instead of harder
# 4               tell me about yourself  I can help you work smarter instead of harder
# ...                                ...                                            ...
# 1587                       can we chat                     Talking is what I do best.
# 1588     I'll be back in a few minutes                               I'll be waiting.
# 1589                      I'll be back                       All right. I'll be here.
# 1590  I'll get back to you in a moment                                Till next time.
# 1591            I promise to come back               Okay. You know where to find me.
#
# [1592 rows x 2 columns]
